# %%
from rag_helper import RAGBase
from ingest import load_faq_data, create_index

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
docs = load_faq_data()
index = create_index(docs)

# %%
assistant = RAGBase(index, openai_client)

# %%
assistant.rag("i just joined the course, how do i get started?")
# Out:
# 'You’re accepted — you can just start learning and submitting homework while the form is open. No confirmation email is needed.'
